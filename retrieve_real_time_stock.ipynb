# %%
import click
import os
import pandas as pd
import random
import time
import urllib2

from BeautifulSoup import BeautifulSoup
from datetime import datetime

DATA_DIR = "/notebooks/stock_data_analysis/data_2"
RANDOM_SLEEP_TIMES = (1, 5)

# This repo "github.com/datasets/s-and-p-500-companies" has some other information about
# S & P 500 companies.
SP500_LIST_URL = "https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents-financials.csv"
SP500_LIST_PATH = os.path.join(DATA_DIR, "constituents-financials.csv")


def _download_sp500_list():
    if os.path.exists(SP500_LIST_PATH):
        return

    f = urllib2.urlopen(SP500_LIST_URL)
    print "Downloading ...", SP500_LIST_URL
    with open(SP500_LIST_PATH, 'w') as fin:
        print >> fin, f.read()
    return

# %%
SP500_LIST_PATH
# Out:
# '/notebooks/stock_data_analysis/data_2/constituents-financials.csv'

# %%
def _load_symbols():
    _download_sp500_list()
    df_sp500 = pd.read_csv(SP500_LIST_PATH)
    df_sp500.sort('Market Cap', ascending=False, inplace=True)
    stock_symbols = df_sp500['Symbol'].unique().tolist()
    print "Loaded %d stock symbols" % len(stock_symbols)
    return stock_symbols

# %%
df_sp500 = pd.read_csv(SP500_LIST_PATH)

# %%
df_sp500.head(100)
# Out:
#    Symbol                           Name                       Sector   Price  \
# 0     MMM                     3M Company                  Industrials  189.09
# 1     ABT            Abbott Laboratories                  Health Care   45.00
# 2    ABBV                         AbbVie                  Health Care   63.69
# 3     ACN                  Accenture plc       Information Technology  124.14
# 4    ATVI            Activision Blizzard       Information Technology   48.06
# 5     AYI              Acuity Brands Inc                  Industrials  205.41
# 6    ADBE              Adobe Systems Inc       Information Technology  119.98
# 7     AAP             Advance Auto Parts       Consumer Discretionary  151.99
# 8     AES                       AES Corp                    Utilities   11.33
# 9     AET                      Aetna Inc                  Health Care  130.59
# 10    AMG  Affiliated Managers Group Inc                   Financials  166.56
# 11    AFL                      AFLAC Inc                   Financials   71.95
# 12      A       Agilent Technologies Inc                  Health Care   51.21
# 13    APD   Air Products & Chemicals Inc                    Materials  139.64
# 14   AKAM        Akamai Technologies Inc       Information Technology   63.30
# 15    ALK           Alaska Air Group Inc                  Industrials   95.12
# 16    ALB                 Albemarle Corp                    Materials  103.79
# 17   ALXN        Alexion Pharmaceuticals                  Health Care  129.18
# 18   ALLE                       Allegion                  Industrials   72.86
# 19    AGN                  Allergan, Plc                  Health Care  239.60
# 20    ADS          Alliance Data Systems       Information Technology  245.05
# 21    LNT            Alliant Energy Corp                    Utilities   39.28
# 22    ALL                  Allstate Corp                   Financials   81.46
# 23  GOOGL           Alphabet Inc Class A       Information Technology  851.15
# 24   GOOG           Alphabet Inc Class C       Information Technology  831.91
# 25     MO               Altria Group Inc             Consumer Staples   76.10
# 26   AMZN                 Amazon.com Inc       Consumer Discretionary  846.02
# 27    AEE                    Ameren Corp                    Utilities   54.82
# 28    AAL        American Airlines Group                  Industrials   44.84
# 29    AEP        American Electric Power                    Utilities   66.24
# ..    ...                            ...                          ...     ...
# 70    HRB                      Block H&R                   Financials   20.84
# 71     BA                 Boeing Company                  Industrials  182.02
# 72    BWA                     BorgWarner       Consumer Discretionary   41.69
# 73    BXP              Boston Properties                  Real Estate  135.66
# 74    BSX              Boston Scientific                  Health Care   24.48
# 75    BMY           Bristol-Myers Squibb                  Health Care   56.33
# 76   AVGO                       Broadcom       Information Technology  219.25
# 77   BF.B             Brown-Forman Corp.             Consumer Staples     NaN
# 78   CHRW       C. H. Robinson Worldwide                  Industrials   78.94
# 79     CA                       CA, Inc.       Information Technology   31.97
# 80    COG                Cabot Oil & Gas                       Energy   22.93
# 81    CPB                  Campbell Soup             Consumer Staples   59.09
# 82    COF          Capital One Financial                   Financials   92.82
# 83    CAH           Cardinal Health Inc.                  Health Care   81.21
# 84    KMX                     Carmax Inc       Consumer Discretionary   63.81
# 85    CCL                 Carnival Corp.       Consumer Discretionary   55.53
# 86    CAT               Caterpillar Inc.                  Industrials   95.93
# 87   CBOE                  CBOE Holdings                   Financials   77.97
# 88    CBG                     CBRE Group                  Real Estate   36.16
# 89    CBS                      CBS Corp.       Consumer Discretionary   67.94
# 90   CELG                  Celgene Corp.                  Health Care  122.08
# 91    CNC            Centene Corporation                  Health Care   70.56
# 92    CNP             CenterPoint Energy                    Utilities   28.00
# 93    CTL                CenturyLink Inc  Telecommunications Services   22.50
# 94   CERN                         Cerner                  Health Care   54.97
# 95     CF     CF Industries Holdings Inc                    Materials   30.20
# 96   SCHW     Charles Schwab Corporation                   Financials   41.66
# 97   CHTR         Charter Communications       Consumer Discretionary  323.24
# 98    CHK              Chesapeake Energy                       Energy    5.26
# 99    CVX                  Chevron Corp.                       Energy  111.81
#
#     Dividend Yield  Price/Earnings  Earnings/Share  Book Value  52 week low  \
# 0             2.48           23.17            8.16       17.26       158.28
# 1             2.34           48.03            0.94       13.94        36.76
# 2             4.04           17.55            3.63        2.91        54.41
# 3             1.96           18.37            6.76       11.95       102.10
# 4             0.64           37.55            1.28       12.23        30.37
# 5             0.25           29.68            6.92       39.50       193.06
# 6             0.00           51.72            2.32       15.02        83.25
# 7             0.15           24.51            6.20       39.66       132.98
# 8             4.16             NaN           -1.71        4.24        10.27
# 9             1.53           20.37            6.41       50.84       104.59
# 10            0.47           19.44            8.57       63.84       130.48
# 11            2.38           11.21            6.42       50.47        59.66
# 12            1.02           32.85            1.56       13.35        37.62
# 13            2.72           53.77            2.60       32.91       123.05
# 14             NaN           35.36            1.79       18.61        47.80
# 15            1.21           14.54            6.54       23.77        54.51
# 16            1.22           18.26            5.68       33.73        58.60
# 17             NaN           73.40            1.76       38.81       109.12
# 18            0.87           30.87            2.36        1.19        61.47
# 19            1.14            6.28           38.18      212.79       184.50
# 20            0.85           33.39            7.34       28.89       185.02
# 21            3.22           24.01            1.64       16.96        34.04
# 22            1.66           17.44            4.67       51.44        63.73
# 23             NaN           30.53           27.88      201.12       672.66
# 24             NaN           29.84           27.88      201.12       663.28
# 25            3.23           10.45            7.28        6.58        59.48
# 26             NaN          172.66            4.90       40.43       538.58
# 27            3.21           20.46            2.68       29.28        46.29
# 28            0.85            9.32            4.81        7.46        24.85
# 29            3.55           53.29            1.24       35.38        57.89
# ..             ...             ...             ...         ...          ...
# 70            4.19           13.38            1.56       -2.64        19.18
# 71            3.12           23.92            7.61        1.32       121.43
# 72            1.30           75.80            0.55       15.16        27.52
# 73            2.21           41.61            3.26       36.32       113.69
# 74             NaN           97.92            0.25        4.94        17.13
# 75            2.72           21.26            2.65        9.68        46.01
# 76            1.87             NaN           -4.73       47.70       139.18
# 77             NaN             NaN            2.96         NaN          NaN
# 78            2.26           21.99            3.59        8.90        65.57
# 79            3.14           16.95            1.89       13.49        29.12
# 80            0.36             NaN           -0.91        5.52        19.77
# 81            2.35           36.82            1.61        4.83        52.58
# 82            1.70           13.47            6.89       98.96        58.03
# 83            2.17           19.55            4.15       17.91        62.70
# 84             NaN           20.22            3.16       16.09        45.06
# 85            2.51           14.93            3.72       31.12        42.94
# 86            3.24             NaN           -0.12       22.40        69.04
# 87            1.28           34.35            2.27        3.91        61.22
# 88             NaN           21.40            1.69        9.07        24.11
# 89            1.06           24.18            2.81        8.95        48.88
# 90             NaN           49.03            2.49        8.48        94.39
# 91             NaN           20.58            3.43       34.29        50.00
# 92            3.84           28.00            1.00        8.03        19.83
# 93            9.20           19.40            1.16       24.52        22.37
# 94             NaN           29.71            1.85       11.92        47.01
# 95            3.88             NaN           -1.19       14.36        20.77
# 96            0.75           31.80            1.31       10.23        23.83
# 97             NaN           20.27           15.95      149.27       182.75
# 98            0.00             NaN          -33.88       -3.59         3.53
# 99            3.80             NaN           -0.27       76.95        89.47
#
#     52 week high  Market Cap    EBITDA  Price/Sales  Price/Book  \
# 0         190.54      112.74   8.70000         3.74       10.95
# 1          45.83       77.76   4.59000         3.74        3.24
# 2          68.12      101.52  10.95000         3.95       21.83
# 3         125.72       77.29   5.66000         2.30       10.32
# 4          48.36       36.13   2.14000         5.44        3.91
# 5         280.89        9.00   0.58620         2.64        5.19
# 6         120.69       59.28   1.82000        10.14        8.00
# 7         177.83       11.18   1.12000         1.19        3.89
# 8          13.32        7.47   3.42000         0.56        2.72
# 9         136.50       45.93   6.20000         0.73        2.58
# 10        179.85        9.44   0.83500         4.32        2.62
# 11         74.50       28.88   4.78000         1.27        1.43
# 12         52.26       16.49   0.94200         3.89        3.84
# 13        150.45       30.38   3.13000         3.18        4.23
# 14         71.64       10.96   0.70798         4.67        3.39
# 15        101.43       11.74   1.82000         2.01        4.07
# 16        105.20       11.68   0.70201         4.29        3.03
# 17        162.00       29.02   1.17000         9.71        3.44
# 18         75.00        6.96   0.47890         3.12       61.57
# 19        299.11       80.32   6.10000         5.58        1.14
# 20        249.22       13.70   1.46000         1.92        8.50
# 21         40.99        8.94   1.03000         2.69        2.31
# 22         83.05       29.74   3.46000         0.81        1.58
# 23        867.00      588.50  29.86000         6.49        4.21
# 24        841.95      575.20  29.86000         6.34        4.12
# 25         76.30      147.64   9.50000         7.58       11.48
# 26        860.86      403.70  11.67000         2.97       20.94
# 27         55.51       13.30   2.30000         2.27        1.87
# 28         50.64       22.61   7.83000         0.57        6.07
# 29         71.32       32.57   5.29000         1.99        1.88
# ..           ...         ...       ...          ...         ...
# 70         29.81        4.32   0.82645         1.43         NaN
# 71        185.71      111.48   8.68000         1.17      136.65
# 72         43.43        8.87   0.80760         0.98        2.76
# 73        144.02       20.87   1.53000         8.14        3.73
# 74         25.65       33.38   2.20000         4.03        5.01
# 75         77.12       94.22   6.70000         4.91        5.89
# 76        224.98       87.48   5.95000         5.57        4.57
# 77           NaN         NaN       NaN          NaN         NaN
# 78         81.16       11.15   0.90080         0.85        8.90
# 79         34.99       13.36   1.28000         3.40        2.43
# 80         26.74       10.67   0.46353         9.01        4.19
# 81         67.89       18.08   1.57000         2.29       12.27
# 82         96.92       44.57   0.00000         2.35        0.94
# 83         87.85       25.62   3.07000         0.20        4.56
# 84         69.11       11.94   1.21000         0.73        3.97
# 85         57.79       40.31   4.76000         2.47        1.79
# 86         99.46       56.26   4.92000         1.46        4.27
# 87         81.36        6.34   0.35726         9.65       19.94
# 88         36.59       12.02   1.20000         0.91        3.96
# 89         68.59       27.82   3.10000         2.11        7.59
# 90        127.00       94.97   4.01000         8.56       14.57
# 91         75.57       12.14   1.97000         0.32        2.07
# 92         28.08       12.06   2.09000         1.60        3.48
# 93         33.45       12.30   6.49000         0.72        0.94
# 94         67.50       18.12   1.32000         3.86        4.62
# 95         37.17        7.04   1.24000         1.95        2.15
# 96         43.36       55.61   0.00000         7.53        4.12
# 97        341.50       86.92  10.73000         3.00        2.17
# 98          8.20        4.67   0.21500         0.61         NaN
# 99        119.00      211.67  13.36000         2.07        1.47
#
#                                           SEC Filings
# 0   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 5   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 6   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 7   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 8   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 9   http://www.sec.gov/cgi-bin/browse-edgar?action...
# 10  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 11  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 12  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 13  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 14  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 15  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 16  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 17  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 18  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 20  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 21  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 22  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 23  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 24  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 25  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 26  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 27  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 28  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 29  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..                                                ...
# 70  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 71  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 72  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 73  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 74  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 75  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 76  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 77  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 78  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 79  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 80  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 81  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 82  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 83  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 84  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 85  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 86  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 87  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 88  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 89  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 90  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 91  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 92  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 93  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 94  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 95  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 96  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 97  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 98  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 99  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [100 rows x 15 columns]

# %%
symbols = _load_symbols()
# Out:
# Downloading ... https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents-financials.csv
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ebde0730f505> in <module>()
# ----> 1 symbols = _load_symbols()
#
# <ipython-input-13-50b2032b4993> in _load_symbols()
#       2     _download_sp500_list()
#       3     df_sp500 = pd.read_csv(SP500_LIST_PATH)
# ----> 4     df_sp500.sort('Market Cap', ascending=False, inplace=True)
#       5     stock_symbols = df_sp500['Symbol'].unique().tolist()
#       6     print "Loaded %d stock symbols" % len(stock_symbols)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
import urllib2
from datetime import datetime
BASE_URL = "https://www.google.com/finance/historical?output=csv&q={0}&startdate=Jan+1%2C+1980&enddate={1}"
symbol_url = BASE_URL.format(
    urllib2.quote('GOOG'), # Replace with any stock you are interested.
    urllib2.quote(datetime.now().strftime("%b+%d,+%Y"), '+')
)

# %%
try:
    f = urllib2.urlopen(symbol_url)
    with open("GOOG.csv", 'w') as fin:
        print >> fin, f.read()
except urllib2.HTTPError:
    print "Fetching Failed: {}".format(symbol_url)
# Out:
# Fetching Failed: https://www.google.com/finance/historical?output=csv&q=GOOG&startdate=Jan+1%2C+1980&enddate=Dec+10%2C+2017

# %%
#https://www.google.com/finance/historical?output=csv&q=[Symbol name]

# %%
import googlefinance.client as gfc

# Dow Jones
param = {
    'q': ".DJI", # Stock symbol (ex: "AAPL")
    'i': "86400", # Interval size in seconds ("86400" = 1 day intervals)
    'x': "INDEXDJX", # Stock exchange symbol on which stock is traded (ex: "NASD")
    'p': "1Y" # Period (Ex: "1Y" = 1 year)
}
# get price data (return pandas dataframe)
df = gfc.get_price_data(param)
print(df)
#
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-45320e5d8d28> in <module>()
#       9 }
#      10 # get price data (return pandas dataframe)
# ---> 11 df = gfc.get_price_data(param)
#      12 print(df)
#      13 #
#
# /usr/local/lib/python2.7/dist-packages/googlefinance/client.pyc in get_price_data(query)
#      13                 cols = price.split(",")
#      14                 if cols[0][0] == 'a':
# ---> 15                         basetime = int(cols[0][1:])
#      16                         index.append(datetime.fromtimestamp(basetime))
#      17                         data.append([float(cols[4]), float(cols[2]), float(cols[3]), float(cols[1]), int(cols[5])])
#
# ValueError: invalid literal for int() with base 10: 'erial vehicles (UAV)'

# %%
#                          Open      High       Low     Close     Volume
# 2016-05-17 05:00:00  17531.76   17755.8  17531.76  17710.71   88436105
# 2016-05-18 05:00:00  17701.46  17701.46  17469.92  17529.98  103253947
# 2016-05-19 05:00:00  17501.28  17636.22  17418.21  17526.62   79038923
# 2016-05-20 05:00:00  17514.16  17514.16  17331.07   17435.4   95531058
# 2016-05-21 05:00:00  17437.32  17571.75  17437.32  17500.94  111992332
# ...                       ...       ...       ...       ...        ...

params = [
	# Dow Jones
	{
		'q': ".DJI",
		'x': "INDEXDJX",
	},
	# NYSE COMPOSITE (DJ)
	{
		'q': "NYA",
		'x': "INDEXNYSEGIS",
	},
	# S&P 500
	{
		'q': ".INX",
		'x': "INDEXSP",
	}
]
period = "1Y"
# get open, high, low, close, volume data (return pandas dataframe)
df = get_prices_data(params, period)
print(df)
#            .DJI_Open  .DJI_High  .DJI_Low  .DJI_Close  .DJI_Volume  \
# 2016-07-20   18503.12   18562.53  18495.11    18559.01    85840786   
# 2016-07-21   18582.70   18622.01  18555.65    18595.03    93233337   
# 2016-07-22   18589.96   18590.44  18469.67    18517.23    86803016   
# 2016-07-23   18524.15   18571.30  18491.59    18570.85    87706622   
# 2016-07-26   18554.49   18555.69  18452.62    18493.06    76807470   
# ...               ...        ...       ...         ...         ...   

params = [
	# Dow Jones
	{
		'q': ".DJI",
		'x': "INDEXDJX",
	},
	# NYSE COMPOSITE (DJ)
	{
		'q': "NYA",
		'x': "INDEXNYSEGIS",
	},
	# S&P 500
	{
		'q': ".INX",
		'x': "INDEXSP",
	}
]
period = "1Y"
interval = 60*30 # 30 minutes
# get open, high, low, close, volume time data (return pandas dataframe)
df = get_prices_time_data(params, period, interval)
print(df)
