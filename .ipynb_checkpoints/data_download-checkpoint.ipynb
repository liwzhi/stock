# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  


from pandas_datareader import data
import fix_yahoo_finance as yf
yf.pdr_override() 


import matplotlib.pyplot as plt
#import statsmodels.tsa.seasonal as smt
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
import datetime as dt
from sklearn import linear_model 

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))
import os
data_path = "/notebooks/stock_data_analysis/data_2/Stocks"
os.chdir(data_path)

filenames = [x for x in os.listdir(data_path) if x.endswith('.txt') and os.path.getsize(x) > 0]

# %%
def get_data(symbol, data_source = 'goole', start_date = '2017-11-15', end_date = '2017-12-10', last_item = 10):
    df = data.get_data_yahoo(symbol, start_date, end_date)
    return df.tail(last_item)

# %%
name_stock = []
data_get = {}
for item in filenames:
    stock_name = item.split(".")[0].upper()
    print stock_name
    name_stock.append(stock_name)
    stock_data = get_data(stock_name)
    if not stock_data.empty:
        data_get[stock_name] = stock_data
# Out:
# A
# [*********************100%***********************]  1 of 1 downloadedAA
# [*********************100%***********************]  1 of 1 downloadedAAAP
# [*********************100%***********************]  1 of 1 downloadedAABA
# [*********************100%***********************]  1 of 1 downloadedAAC
# [*********************100%***********************]  1 of 1 downloadedAAL
# [*********************100%***********************]  1 of 1 downloadedAAMC
# [*********************100%***********************]  1 of 1 downloadedAAME
# [*********************100%***********************]  1 of 1 downloadedAAN
# [*********************100%***********************]  1 of 1 downloadedAAOI
# [*********************100%***********************]  1 of 1 downloadedAAON
# [*********************100%***********************]  1 of 1 downloadedAAP
# [*********************100%***********************]  1 of 1 downloadedAAPL
# [*********************100%***********************]  1 of 1 downloadedAAT
# [*********************100%***********************]  1 of 1 downloadedAAU
# [*********************100%***********************]  1 of 1 downloadedAAV
# [*********************100%***********************]  1 of 1 downloadedAAWW
# [*********************100%***********************]  1 of 1 downloadedAAXN
# [*********************100%***********************]  1 of 1 downloadedAB
# [*********************100%***********************]  1 of 1 downloadedABAC
# [*********************100%***********************]  1 of 1 downloadedABAX
# [*********************100%***********************]  1 of 1 downloadedABB
# [*********************100%***********************]  1 of 1 downloadedABBV
# [*********************100%***********************]  1 of 1 downloadedABC
# [*********************100%***********************]  1 of 1 downloadedABCB
# [*********************100%***********************]  1 of 1 downloadedABCD
# [*********************100%***********************]  1 of 1 downloadedABCO
# [*********************100%***********************]  1 of 1 downloadedABDC
# [*********************100%***********************]  1 of 1 downloadedABE
# [*********************100%***********************]  1 of 1 downloadedABEO
# [*********************100%***********************]  1 of 1 downloadedABEOW
# [*********************100%***********************]  1 of 1 downloadedABEV
# [*********************100%***********************]  1 of 1 downloadedABG
# [*********************100%***********************]  1 of 1 downloadedABIL
# [*********************100%***********************]  1 of 1 downloadedABIO
# [*********************100%***********************]  1 of 1 downloadedABLX
# [*********************100%***********************]  1 of 1 downloadedABM
# [*********************100%***********************]  1 of 1 downloadedABMD
# [*********************100%***********************]  1 of 1 downloadedABR
# [*********************100%***********************]  1 of 1 downloadedABR_A
# [*********************100%***********************]  1 of 1 downloadedABR_B
# [*********************100%***********************]  1 of 1 downloadedABR_C
# [*********************100%***********************]  1 of 1 downloadedABRN
# [*********************100%***********************]  1 of 1 downloadedABT
# [*********************100%***********************]  1 of 1 downloadedABTX
# [*********************100%***********************]  1 of 1 downloadedABUS
# [*********************100%***********************]  1 of 1 downloadedABX
# [*********************100%***********************]  1 of 1 downloadedABY
# [*********************100%***********************]  1 of 1 downloadedAC
# [*********************100%***********************]  1 of 1 downloadedACAD
# [*********************100%***********************]  1 of 1 downloadedACBI
# [*********************100%***********************]  1 of 1 downloadedACC
# [*********************100%***********************]  1 of 1 downloadedACCO
# [*********************100%***********************]  1 of 1 downloadedACER
# [*********************100%***********************]  1 of 1 downloadedACERW
# [*********************100%***********************]  1 of 1 downloadedACET
# [*********************100%***********************]  1 of 1 downloadedACFC
# [*********************100%***********************]  1 of 1 downloadedACGL
# [*********************100%***********************]  1 of 1 downloadedACGLO
# [*********************100%***********************]  1 of 1 downloadedACGLP
# [*********************100%***********************]  1 of 1 downloadedACH
# [*********************100%***********************]  1 of 1 downloadedACHC
# [*********************100%***********************]  1 of 1 downloadedACHN
# [*********************100%***********************]  1 of 1 downloadedACHV
# [*********************100%***********************]  1 of 1 downloadedACIA
# [*********************100%***********************]  1 of 1 downloadedACIU
# [*********************100%***********************]  1 of 1 downloadedACIW
# [*********************100%***********************]  1 of 1 downloadedACLS
# [*********************100%***********************]  1 of 1 downloadedACM
# [*********************100%***********************]  1 of 1 downloadedACMR
# [*********************100%***********************]  1 of 1 downloadedACN
# [*********************100%***********************]  1 of 1 downloadedACNB
# [*********************100%***********************]  1 of 1 downloadedACOR
# [*********************100%***********************]  1 of 1 downloadedACP
# [*********************100%***********************]  1 of 1 downloadedACRE
# [*********************100%***********************]  1 of 1 downloadedACRS
# [*********************100%***********************]  1 of 1 downloadedACRX
# [*********************100%***********************]  1 of 1 downloadedACSF
# [*********************100%***********************]  1 of 1 downloadedACSI
# [*********************100%***********************]  1 of 1 downloadedACST
# [*********************100%***********************]  1 of 1 downloadedACTA
# [*********************100%***********************]  1 of 1 downloadedACTG
# [*********************100%***********************]  1 of 1 downloadedACU
# [*********************100%***********************]  1 of 1 downloadedACV
# [*********************100%***********************]  1 of 1 downloadedACXM
# [*********************100%***********************]  1 of 1 downloadedACY
# [*********************100%***********************]  1 of 1 downloadedADAP
# [*********************100%***********************]  1 of 1 downloadedADBE
# [*********************100%***********************]  1 of 1 downloadedADC
# [*********************100%***********************]  1 of 1 downloadedADES
# [*********************100%***********************]  1 of 1 downloadedADHD
# [*********************100%***********************]  1 of 1 downloadedADI
# [*********************100%***********************]  1 of 1 downloadedADM
# [*********************100%***********************]  1 of 1 downloadedADMA
# [*********************100%***********************]  1 of 1 downloadedADMP
# [*********************100%***********************]  1 of 1 downloadedADMS
# [*********************100%***********************]  1 of 1 downloadedADNT
# [*********************100%***********************]  1 of 1 downloadedADOM
# [*********************100%***********************]  1 of 1 downloadedADP
# [*********************100%***********************]  1 of 1 downloadedADRO
# [*********************100%***********************]  1 of 1 downloadedADS
# [*********************100%***********************]  1 of 1 downloadedADSK
# [*********************100%***********************]  1 of 1 downloadedADSW
# [*********************100%***********************]  1 of 1 downloadedADTN
# [*********************100%***********************]  1 of 1 downloadedADUS
# [*********************100%***********************]  1 of 1 downloadedADVM
# [*********************100%***********************]  1 of 1 downloadedADX
# [*********************100%***********************]  1 of 1 downloadedADXS
# [*********************100%***********************]  1 of 1 downloadedADXSW
# [*********************100%***********************]  1 of 1 downloadedAE
# [*********************100%***********************]  1 of 1 downloadedAEB
# [*********************100%***********************]  1 of 1 downloadedAED
# [*********************100%***********************]  1 of 1 downloadedAEE
# [*********************100%***********************]  1 of 1 downloadedAEG
# [*********************100%***********************]  1 of 1 downloadedAEGN
# [*********************100%***********************]  1 of 1 downloadedAEH
# [*********************100%***********************]  1 of 1 downloadedAEHR
# [*********************100%***********************]  1 of 1 downloadedAEIS
# [*********************100%***********************]  1 of 1 downloadedAEK
# [*********************100%***********************]  1 of 1 downloadedAEL
# [*********************100%***********************]  1 of 1 downloadedAEM
# [*********************100%***********************]  1 of 1 downloadedAEMD
# [*********************100%***********************]  1 of 1 downloadedAEO
# [*********************100%***********************]  1 of 1 downloadedAEP
# [*********************100%***********************]  1 of 1 downloadedAER
# [*********************100%***********************]  1 of 1 downloadedAERI
# [*********************100%***********************]  1 of 1 downloadedAES
# [*********************100%***********************]  1 of 1 downloadedAET
# [*********************100%***********************]  1 of 1 downloadedAETI
# [*********************100%***********************]  1 of 1 downloadedAEUA
# [*********************100%***********************]  1 of 1 downloadedAEY
# [*********************100%***********************]  1 of 1 downloadedAEZS
# [*********************100%***********************]  1 of 1 downloadedAFAM
# [*********************100%***********************]  1 of 1 downloadedAFB
# [*********************100%***********************]  1 of 1 downloadedAFC
# [*********************100%***********************]  1 of 1 downloadedAFG
# [*********************100%***********************]  1 of 1 downloadedAFGE
# [*********************100%***********************]  1 of 1 downloadedAFGH
# [*********************100%***********************]  1 of 1 downloadedAFH
# [*********************100%***********************]  1 of 1 downloadedAFHBL
# [*********************100%***********************]  1 of 1 downloadedAFI
# [*********************100%***********************]  1 of 1 downloadedAFL
# [*********************100%***********************]  1 of 1 downloadedAFMD
# [*********************100%***********************]  1 of 1 downloadedAFSD
# [*********************100%***********************]  1 of 1 downloadedAFSI
# [*********************100%***********************]  1 of 1 downloadedAFSI_A
# [*********************100%***********************]  1 of 1 downloadedAFSI_B
# [*********************100%***********************]  1 of 1 downloadedAFSI_C
# [*********************100%***********************]  1 of 1 downloadedAFSI_D
# [*********************100%***********************]  1 of 1 downloadedAFSI_E
# [*********************100%***********************]  1 of 1 downloadedAFSI_F
# [*********************100%***********************]  1 of 1 downloadedAFSS
# [*********************100%***********************]  1 of 1 downloadedAFST
# [*********************100%***********************]  1 of 1 downloadedAFT
# [*********************100%***********************]  1 of 1 downloadedAFTY
# [*********************100%***********************]  1 of 1 downloadedAG
# [*********************100%***********************]  1 of 1 downloadedAGC
# [*********************100%***********************]  1 of 1 downloadedAGCO
# [*********************100%***********************]  1 of 1 downloadedAGD
# [*********************100%***********************]  1 of 1 downloadedAGEN
# [*********************100%***********************]  1 of 1 downloadedAGFS
# [*********************100%***********************]  1 of 1 downloadedAGFSW
# [*********************100%***********************]  1 of 1 downloadedAGGE
# [*********************100%***********************]  1 of 1 downloadedAGGP
# [*********************100%***********************]  1 of 1 downloadedAGGY
# [*********************100%***********************]  1 of 1 downloadedAGI
# [*********************100%***********************]  1 of 1 downloadedAGII
# [*********************100%***********************]  1 of 1 downloadedAGIIL
# [*********************100%***********************]  1 of 1 downloadedAGIO
# [*********************100%***********************]  1 of 1 downloadedAGLE
# [*********************100%***********************]  1 of 1 downloadedAGM-A
# [*********************100%***********************]  1 of 1 downloadedAGM
# [*********************100%***********************]  1 of 1 downloadedAGM_A
# [*********************100%***********************]  1 of 1 downloadedAGM_B
# [*********************100%***********************]  1 of 1 downloadedAGM_C
# [*********************100%***********************]  1 of 1 downloadedAGN
# [*********************100%***********************]  1 of 1 downloadedAGN_A
# [*********************100%***********************]  1 of 1 downloadedAGNC
# [*********************100%***********************]  1 of 1 downloadedAGNCB
# [*********************100%***********************]  1 of 1 downloadedAGNCN
# [*********************100%***********************]  1 of 1 downloadedAGO
# [*********************100%***********************]  1 of 1 downloadedAGO_B
# [*********************100%***********************]  1 of 1 downloadedAGO_E
# [*********************100%***********************]  1 of 1 downloadedAGO_F
# [*********************100%***********************]  1 of 1 downloadedAGR
# [*********************100%***********************]  1 of 1 downloadedAGRO
# [*********************100%***********************]  1 of 1 downloadedAGRX
# [*********************100%***********************]  1 of 1 downloadedAGT
# [*********************100%***********************]  1 of 1 downloadedAGTC
# [*********************100%***********************]  1 of 1 downloadedAGU
# [*********************100%***********************]  1 of 1 downloadedAGX
# [*********************100%***********************]  1 of 1 downloadedAGYS
# [*********************100%***********************]  1 of 1 downloadedAHC
# [*********************100%***********************]  1 of 1 downloadedAHGP
# [*********************100%***********************]  1 of 1 downloadedAHH
# [*********************100%***********************]  1 of 1 downloadedAHL
# [*********************100%***********************]  1 of 1 downloadedAHL_C
# [*********************100%***********************]  1 of 1 downloadedAHL_D
# [*********************100%***********************]  1 of 1 downloadedAHP
# [*********************100%***********************]  1 of 1 downloadedAHP_B
# [*********************100%***********************]  1 of 1 downloadedAHPA
# [*********************100%***********************]  1 of 1 downloadedAHPAU
# [*********************100%***********************]  1 of 1 downloadedAHPAW
# [*********************100%***********************]  1 of 1 downloadedAHPI
# [*********************100%***********************]  1 of 1 downloadedAHT
# [*********************100%***********************]  1 of 1 downloadedAHT_D
# [*********************100%***********************]  1 of 1 downloadedAHT_F
# [*********************100%***********************]  1 of 1 downloadedAHT_G
# [*********************100%***********************]  1 of 1 downloadedAHT_H
# [*********************100%***********************]  1 of 1 downloadedAI
# [*********************100%***********************]  1 of 1 downloadedAI_B
# [*********************100%***********************]  1 of 1 downloadedAIB-CL
# [*********************100%***********************]  1 of 1 downloadedAIC
# [*********************100%***********************]  1 of 1 downloadedAIEQ
# [*********************100%***********************]  1 of 1 downloadedAIF
# [*********************100%***********************]  1 of 1 downloadedAIG-WS
# [*********************100%***********************]  1 of 1 downloadedAIG
# [*********************100%***********************]  1 of 1 downloadedAIMC
# [*********************100%***********************]  1 of 1 downloadedAIMT
# [*********************100%***********************]  1 of 1 downloadedAIN
# [*********************100%***********************]  1 of 1 downloadedAINC
# [*********************100%***********************]  1 of 1 downloadedAINV
# [*********************100%***********************]  1 of 1 downloadedAIR
# [*********************100%***********************]  1 of 1 downloadedAIRG
# [*********************100%***********************]  1 of 1 downloadedAIRI
# [*********************100%***********************]  1 of 1 downloadedAIRT
# [*********************100%***********************]  1 of 1 downloadedAIT
# [*********************100%***********************]  1 of 1 downloadedAIV
# [*********************100%***********************]  1 of 1 downloadedAIV_A
# [*********************100%***********************]  1 of 1 downloadedAIW
# [*********************100%***********************]  1 of 1 downloadedAIY
# [*********************100%***********************]  1 of 1 downloadedAIZ
# [*********************100%***********************]  1 of 1 downloadedAJG
# [*********************100%***********************]  1 of 1 downloadedAJRD
# [*********************100%***********************]  1 of 1 downloadedAJX
# [*********************100%***********************]  1 of 1 downloadedAJXA
# [*********************100%***********************]  1 of 1 downloadedAKAM
# [*********************100%***********************]  1 of 1 downloadedAKAO
# [*********************100%***********************]  1 of 1 downloadedAKBA
# [*********************100%***********************]  1 of 1 downloadedAKCA
# [*********************100%***********************]  1 of 1 downloadedAKER
# [*********************100%***********************]  1 of 1 downloadedAKG
# [*********************100%***********************]  1 of 1 downloadedAKO-A
# [*********************100%***********************]  1 of 1 downloadedAKO-B
# [*********************100%***********************]  1 of 1 downloadedAKP
# [*********************100%***********************]  1 of 1 downloadedAKR
# [*********************100%***********************]  1 of 1 downloadedAKRX
# [*********************100%***********************]  1 of 1 downloadedAKS
# [*********************100%***********************]  1 of 1 downloadedAKTS
# [*********************100%***********************]  1 of 1 downloadedAKTX
# [*********************100%***********************]  1 of 1 downloadedAL
# [*********************100%***********************]  1 of 1 downloadedALB
# [*********************100%***********************]  1 of 1 downloadedALBO
# [*********************100%***********************]  1 of 1 downloadedALCO
# [*********************100%***********************]  1 of 1 downloadedALDR
# [*********************100%***********************]  1 of 1 downloadedALDW
# [*********************100%***********************]  1 of 1 downloadedALDX
# [*********************100%***********************]  1 of 1 downloadedALE
# [*********************100%***********************]  1 of 1 downloadedALEX
# [*********************100%***********************]  1 of 1 downloadedALFI
# [*********************100%***********************]  1 of 1 downloadedALG
# [*********************100%***********************]  1 of 1 downloadedALGN
# [*********************100%***********************]  1 of 1 downloadedALGT
# [*********************100%***********************]  1 of 1 downloadedALIM
# [*********************100%***********************]  1 of 1 downloadedALJJ
# [*********************100%***********************]  1 of 1 downloadedALK
# [*********************100%***********************]  1 of 1 downloadedALKS
# [*********************100%***********************]  1 of 1 downloadedALL
# [*********************100%***********************]  1 of 1 downloadedALL_A
# [*********************100%***********************]  1 of 1 downloadedALL_B
# [*********************100%***********************]  1 of 1 downloadedALL_C
# [*********************100%***********************]  1 of 1 downloadedALL_D
# [*********************100%***********************]  1 of 1 downloadedALL_E
# [*********************100%***********************]  1 of 1 downloadedALL_F
# [*********************100%***********************]  1 of 1 downloadedALLE
# [*********************100%***********************]  1 of 1 downloadedALLT
# [*********************100%***********************]  1 of 1 downloadedALLY
# [*********************100%***********************]  1 of 1 downloadedALLY_A
# [*********************100%***********************]  1 of 1 downloadedALN
# [*********************100%***********************]  1 of 1 downloadedALNA
# [*********************100%***********************]  1 of 1 downloadedALNY
# [*********************100%***********************]  1 of 1 downloadedALO
# [*********************100%***********************]  1 of 1 downloadedALOG
# [*********************100%***********************]  1 of 1 downloadedALOT
# [*********************100%***********************]  1 of 1 downloadedALP_O-CL
# [*********************100%***********************]  1 of 1 downloadedALP_Q
# [*********************100%***********************]  1 of 1 downloadedALPN
# [*********************100%***********************]  1 of 1 downloadedALQA
# [*********************100%***********************]  1 of 1 downloadedALRM
# [*********************100%***********************]  1 of 1 downloadedALRN
# [*********************100%***********************]  1 of 1 downloadedALSK
# [*********************100%***********************]  1 of 1 downloadedALSN
# [*********************100%***********************]  1 of 1 downloadedALT
# [*********************100%***********************]  1 of 1 downloadedALTR
# [*********************100%***********************]  1 of 1 downloadedALTY
# [*********************100%***********************]  1 of 1 downloadedALV
# [*********************100%***********************]  1 of 1 downloadedALX
# [*********************100%***********************]  1 of 1 downloadedALXN
# [*********************100%***********************]  1 of 1 downloadedAM
# [*********************100%***********************]  1 of 1 downloadedAMAG
# [*********************100%***********************]  1 of 1 downloadedAMAT
# [*********************100%***********************]  1 of 1 downloadedAMBA
# [*********************100%***********************]  1 of 1 downloadedAMBC
# [*********************100%***********************]  1 of 1 downloadedAMBCW
# [*********************100%***********************]  1 of 1 downloadedAMBR
# [*********************100%***********************]  1 of 1 downloadedAMC
# [*********************100%***********************]  1 of 1 downloadedAMCA
# [*********************100%***********************]  1 of 1 downloadedAMCN
# [*********************100%***********************]  1 of 1 downloadedAMCX
# [*********************100%***********************]  1 of 1 downloadedAMD
# [*********************100%***********************]  1 of 1 downloadedAMDA
# [*********************100%***********************]  1 of 1 downloadedAME
# [*********************100%***********************]  1 of 1 downloadedAMED
# [*********************100%***********************]  1 of 1 downloadedAMFW
# [*********************100%***********************]  1 of 1 downloadedAMG
# [*********************100%***********************]  1 of 1 downloadedAMGN
# [*********************100%***********************]  1 of 1 downloadedAMGP
# [*********************100%***********************]  1 of 1 downloadedAMH
# [*********************100%***********************]  1 of 1 downloadedAMH_C
# [*********************100%***********************]  1 of 1 downloadedAMH_D
# [*********************100%***********************]  1 of 1 downloadedAMH_E
# [*********************100%***********************]  1 of 1 downloadedAMH_F
# [*********************100%***********************]  1 of 1 downloadedAMH_G
# [*********************100%***********************]  1 of 1 downloadedAMID
# [*********************100%***********************]  1 of 1 downloadedAMKR
# [*********************100%***********************]  1 of 1 downloadedAMLX
# [*********************100%***********************]  1 of 1 downloadedAMMA
# [*********************100%***********************]  1 of 1 downloadedAMN
# [*********************100%***********************]  1 of 1 downloadedAMNB
# [*********************100%***********************]  1 of 1 downloadedAMOT
# [*********************100%***********************]  1 of 1 downloadedAMOV
# [*********************100%***********************]  1 of 1 downloadedAMP
# [*********************100%***********************]  1 of 1 downloadedAMPE
# [*********************100%***********************]  1 of 1 downloadedAMPH
# [*********************100%***********************]  1 of 1 downloadedAMRB
# [*********************100%***********************]  1 of 1 downloadedAMRC
# [*********************100%***********************]  1 of 1 downloadedAMRK
# [*********************100%***********************]  1 of 1 downloadedAMRN
# [*********************100%***********************]  1 of 1 downloadedAMRS
# [*********************100%***********************]  1 of 1 downloadedAMS
# [*********************100%***********************]  1 of 1 downloadedAMSC
# [*********************100%***********************]  1 of 1 downloadedAMSF
# [*********************100%***********************]  1 of 1 downloadedAMSWA
# [*********************100%***********************]  1 of 1 downloadedAMT
# [*********************100%***********************]  1 of 1 downloadedAMT_B
# [*********************100%***********************]  1 of 1 downloadedAMTD
# [*********************100%***********************]  1 of 1 downloadedAMTX
# [*********************100%***********************]  1 of 1 downloadedAMWD
# [*********************100%***********************]  1 of 1 downloadedAMX
# [*********************100%***********************]  1 of 1 downloadedAMZA
# [*********************100%***********************]  1 of 1 downloadedAMZN
# [*********************100%***********************]  1 of 1 downloadedAN
# [*********************100%***********************]  1 of 1 downloadedANAB
# [*********************100%***********************]  1 of 1 downloadedANAT
# [*********************100%***********************]  1 of 1 downloadedANCB
# [*********************100%***********************]  1 of 1 downloadedANCX
# [*********************100%***********************]  1 of 1 downloadedANDA
# [*********************100%***********************]  1 of 1 downloadedANDAR
# [*********************100%***********************]  1 of 1 downloadedANDAU
# [*********************100%***********************]  1 of 1 downloadedANDAW
# [*********************100%***********************]  1 of 1 downloadedANDE
# [*********************100%***********************]  1 of 1 downloadedANDV
# [*********************100%***********************]  1 of 1 downloadedANDX
# [*********************100%***********************]  1 of 1 downloadedANET
# [*********************100%***********************]  1 of 1 downloadedANF
# [*********************100%***********************]  1 of 1 downloadedANFI
# [*********************100%***********************]  1 of 1 downloadedANGI
# [*********************100%***********************]  1 of 1 downloadedANGO
# [*********************100%***********************]  1 of 1 downloadedANH
# [*********************100%***********************]  1 of 1 downloadedANH_A
# [*********************100%***********************]  1 of 1 downloadedANH_B
# [*********************100%***********************]  1 of 1 downloadedANH_C
# [*********************100%***********************]  1 of 1 downloadedANIK
# [*********************100%***********************]  1 of 1 downloadedANIP
# [*********************100%***********************]  1 of 1 downloadedANSS
# [*********************100%***********************]  1 of 1 downloadedANTH
# [*********************100%***********************]  1 of 1 downloadedANTM
# [*********************100%***********************]  1 of 1 downloadedANTX
# [*********************100%***********************]  1 of 1 downloadedANW
# [*********************100%***********************]  1 of 1 downloadedANY
# [*********************100%***********************]  1 of 1 downloadedAOBC
# [*********************100%***********************]  1 of 1 downloadedAOD
# [*********************100%***********************]  1 of 1 downloadedAOI
# [*********************100%***********************]  1 of 1 downloadedAON
# [*********************100%***********************]  1 of 1 downloadedAOS
# [*********************100%***********************]  1 of 1 downloadedAOSL
# [*********************100%***********************]  1 of 1 downloadedAOXG
# [*********************100%***********************]  1 of 1 downloadedAP
# [*********************100%***********************]  1 of 1 downloadedAPA
# [*********************100%***********************]  1 of 1 downloadedAPAM
# [*********************100%***********************]  1 of 1 downloadedAPB
# [*********************100%***********************]  1 of 1 downloadedAPC
# [*********************100%***********************]  1 of 1 downloadedAPD
# [*********************100%***********************]  1 of 1 downloadedAPDN
# [*********************100%***********************]  1 of 1 downloadedAPDNW
# [*********************100%***********************]  1 of 1 downloadedAPEI
# [*********************100%***********************]  1 of 1 downloadedAPEN
# [*********************100%***********************]  1 of 1 downloadedAPF
# [*********************100%***********************]  1 of 1 downloadedAPH
# [*********************100%***********************]  1 of 1 downloadedAPHB
# [*********************100%***********************]  1 of 1 downloadedAPLE
# [*********************100%***********************]  1 of 1 downloadedAPLP
# [*********************100%***********************]  1 of 1 downloadedAPLS
# [*********************100%***********************]  1 of 1 downloadedAPO
# [*********************100%***********************]  1 of 1 downloadedAPO_A
# [*********************100%***********************]  1 of 1 downloadedAPOG
# [*********************100%***********************]  1 of 1 downloadedAPOP
# [*********************100%***********************]  1 of 1 downloadedAPOPW
# [*********************100%***********************]  1 of 1 downloadedAPPF
# [*********************100%***********************]  1 of 1 downloadedAPPN
# [*********************100%***********************]  1 of 1 downloadedAPPS
# [*********************100%***********************]  1 of 1 downloadedAPRI
# [*********************100%***********************]  1 of 1 downloadedAPRN
# [*********************100%***********************]  1 of 1 downloadedAPT
# [*********************100%***********************]  1 of 1 downloadedAPTI
# [*********************100%***********************]  1 of 1 downloadedAPTO
# [*********************100%***********************]  1 of 1 downloadedAPTS
# [*********************100%***********************]  1 of 1 downloadedAPU
# [*********************100%***********************]  1 of 1 downloadedAPVO
# [*********************100%***********************]  1 of 1 downloadedAPWC
# [*********************100%***********************]  1 of 1 downloadedAQ
# [*********************100%***********************]  1 of 1 downloadedAQB
# [*********************100%***********************]  1 of 1 downloadedAQMS
# [*********************100%***********************]  1 of 1 downloadedAQN
# [*********************100%***********************]  1 of 1 downloadedAQUA
# [*********************100%***********************]  1 of 1 downloadedAQXP
# [*********************100%***********************]  1 of 1 downloadedAR
# [*********************100%***********************]  1 of 1 downloadedARA
# [*********************100%***********************]  1 of 1 downloadedARAY
# [*********************100%***********************]  1 of 1 downloadedARC
# [*********************100%***********************]  1 of 1 downloadedARCB
# [*********************100%***********************]  1 of 1 downloadedARCC
# [*********************100%***********************]  1 of 1 downloadedARCH
# [*********************100%***********************]  1 of 1 downloadedARCI
# [*********************100%***********************]  1 of 1 downloadedARCM
# [*********************100%***********************]  1 of 1 downloadedARCO
# [*********************100%***********************]  1 of 1 downloadedARCW
# [*********************100%***********************]  1 of 1 downloadedARCX
# [*********************100%***********************]  1 of 1 downloadedARD
# [*********************100%***********************]  1 of 1 downloadedARDC
# [*********************100%***********************]  1 of 1 downloadedARDM
# [*********************100%***********************]  1 of 1 downloadedARDX
# [*********************100%***********************]  1 of 1 downloadedARE
# [*********************100%***********************]  1 of 1 downloadedARE_D
# [*********************100%***********************]  1 of 1 downloadedARES
# [*********************100%***********************]  1 of 1 downloadedARES_A
# [*********************100%***********************]  1 of 1 downloadedAREX
# [*********************100%***********************]  1 of 1 downloadedARGS
# [*********************100%***********************]  1 of 1 downloadedARGX
# [*********************100%***********************]  1 of 1 downloadedARH_C
# [*********************100%***********************]  1 of 1 downloadedARI
# [*********************100%***********************]  1 of 1 downloadedARI_C
# [*********************100%***********************]  1 of 1 downloadedARII
# [*********************100%***********************]  1 of 1 downloadedARKG
# [*********************100%***********************]  1 of 1 downloadedARKK
# [*********************100%***********************]  1 of 1 downloadedARKQ
# [*********************100%***********************]  1 of 1 downloadedARKR
# [*********************100%***********************]  1 of 1 downloadedARKW
# [*********************100%***********************]  1 of 1 downloadedARL
# [*********************100%***********************]  1 of 1 downloadedARLP
# [*********************100%***********************]  1 of 1 downloadedARLZ
# [*********************100%***********************]  1 of 1 downloadedARMK
# [*********************100%***********************]  1 of 1 downloadedARNA
# [*********************100%***********************]  1 of 1 downloadedARNC
# [*********************100%***********************]  1 of 1 downloadedARNC_
# [*********************100%***********************]  1 of 1 downloadedARNC_B
# [*********************100%***********************]  1 of 1 downloadedAROC
# [*********************100%***********************]  1 of 1 downloadedAROW
# [*********************100%***********************]  1 of 1 downloadedARQL
# [*********************100%***********************]  1 of 1 downloadedARR
# [*********************100%***********************]  1 of 1 downloadedARR_A
# [*********************100%***********************]  1 of 1 downloadedARR_B
# [*********************100%***********************]  1 of 1 downloadedARRS
# [*********************100%***********************]  1 of 1 downloadedARRY
# [*********************100%***********************]  1 of 1 downloadedARTNA
# [*********************100%***********************]  1 of 1 downloadedARTW
# [*********************100%***********************]  1 of 1 downloadedARTX
# [*********************100%***********************]  1 of 1 downloadedARW
# [*********************100%***********************]  1 of 1 downloadedARWR
# [*********************100%***********************]  1 of 1 downloadedASA
# [*********************100%***********************]  1 of 1 downloadedASB-WS
# [*********************100%***********************]  1 of 1 downloadedASB
# [*********************100%***********************]  1 of 1 downloadedASB_C
# [*********************100%***********************]  1 of 1 downloadedASB_D
# [*********************100%***********************]  1 of 1 downloadedASC
# [*********************100%***********************]  1 of 1 downloadedASCMA
# [*********************100%***********************]  1 of 1 downloadedASET
# [*********************100%***********************]  1 of 1 downloadedASFI
# [*********************100%***********************]  1 of 1 downloadedASG
# [*********************100%***********************]  1 of 1 downloadedASGN
# [*********************100%***********************]  1 of 1 downloadedASH
# [*********************100%***********************]  1 of 1 downloadedASHX
# [*********************100%***********************]  1 of 1 downloadedASIX
# [*********************100%***********************]  1 of 1 downloadedASM
# [*********************100%***********************]  1 of 1 downloadedASMB
# [*********************100%***********************]  1 of 1 downloadedASML
# [*********************100%***********************]  1 of 1 downloadedASNA
# [*********************100%***********************]  1 of 1 downloadedASND
# [*********************100%***********************]  1 of 1 downloadedASPN
# [*********************100%***********************]  1 of 1 downloadedASPS
# [*********************100%***********************]  1 of 1 downloadedASPU
# [*********************100%***********************]  1 of 1 downloadedASR
# [*********************100%***********************]  1 of 1 downloadedASRV
# [*********************100%***********************]  1 of 1 downloadedASRVP
# [*********************100%***********************]  1 of 1 downloadedAST
# [*********************100%***********************]  1 of 1 downloadedASTC
# [*********************100%***********************]  1 of 1 downloadedASTE
# [*********************100%***********************]  1 of 1 downloadedASUR
# [*********************100%***********************]  1 of 1 downloadedASV
# [*********************100%***********************]  1 of 1 downloadedASX
# [*********************100%***********************]  1 of 1 downloadedASYS
# [*********************100%***********************]  1 of 1 downloadedAT
# [*********************100%***********************]  1 of 1 downloadedATAC
# [*********************100%***********************]  1 of 1 downloadedATACR
# [*********************100%***********************]  1 of 1 downloadedATACU
# [*********************100%***********************]  1 of 1 downloadedATAI
# [*********************100%***********************]  1 of 1 downloadedATAX
# [*********************100%***********************]  1 of 1 downloadedATEC
# [*********************100%***********************]  1 of 1 downloadedATEN
# [*********************100%***********************]  1 of 1 downloadedATGE
# [*********************100%***********************]  1 of 1 downloadedATH
# [*********************100%***********************]  1 of 1 downloadedATHM
# [*********************100%***********************]  1 of 1 downloadedATHN
# [*********************100%***********************]  1 of 1 downloadedATHX
# [*********************100%***********************]  1 of 1 downloadedATI
# [*********************100%***********************]  1 of 1 downloadedATKR
# [*********************100%***********************]  1 of 1 downloadedATLC
# [*********************100%***********************]  1 of 1 downloadedATLO
# [*********************100%***********************]  1 of 1 downloadedATNI
# [*********************100%***********************]  1 of 1 downloadedATNM
# [*********************100%***********************]  1 of 1 downloadedATNX
# [*********************100%***********************]  1 of 1 downloadedATO
# [*********************100%***********************]  1 of 1 downloadedATOM
# [*********************100%***********************]  1 of 1 downloadedATOS
# [*********************100%***********************]  1 of 1 downloadedATR
# [*********************100%***********************]  1 of 1 downloadedATRA
# [*********************100%***********************]  1 of 1 downloadedATRC
# [*********************100%***********************]  1 of 1 downloadedATRI
# [*********************100%***********************]  1 of 1 downloadedATRO
# [*********************100%***********************]  1 of 1 downloadedATRS
# [*********************100%***********************]  1 of 1 downloadedATSG
# [*********************100%***********************]  1 of 1 downloadedATTO
# [*********************100%***********************]  1 of 1 downloadedATTU
# [*********************100%***********************]  1 of 1 downloadedATU
# [*********************100%***********************]  1 of 1 downloadedATUS
# [*********************100%***********************]  1 of 1 downloadedATV
# [*********************100%***********************]  1 of 1 downloadedATVI
# [*********************100%***********************]  1 of 1 downloadedATXI
# [*********************100%***********************]  1 of 1 downloadedAU
# [*********************100%***********************]  1 of 1 downloadedAUBN
# [*********************100%***********************]  1 of 1 downloadedAUDC
# [*********************100%***********************]  1 of 1 downloadedAUG
# [*********************100%***********************]  1 of 1 downloadedAUMN
# [*********************100%***********************]  1 of 1 downloadedAUO
# [*********************100%***********************]  1 of 1 downloadedAUPH
# [*********************100%***********************]  1 of 1 downloadedAUTO
# [*********************100%***********************]  1 of 1 downloadedAUY
# [*********************100%***********************]  1 of 1 downloadedAVA
# [*********************100%***********************]  1 of 1 downloadedAVAL
# [*********************100%***********************]  1 of 1 downloadedAVAV
# [*********************100%***********************]  1 of 1 downloadedAVB
# [*********************100%***********************]  1 of 1 downloadedAVD
# [*********************100%***********************]  1 of 1 downloadedAVDL
# [*********************100%***********************]  1 of 1 downloadedAVEO
# [*********************100%***********************]  1 of 1 downloadedAVGO
# [*********************100%***********************]  1 of 1 downloadedAVGR
# [*********************100%***********************]  1 of 1 downloadedAVH
# [*********************100%***********************]  1 of 1 downloadedAVHI
# [*********************100%***********************]  1 of 1 downloadedAVID
# [*********************100%***********************]  1 of 1 downloadedAVIR
# [*********************100%***********************]  1 of 1 downloadedAVK
# [*********************100%***********************]  1 of 1 downloadedAVNW
# [*********************100%***********************]  1 of 1 downloadedAVP
# [*********************100%***********************]  1 of 1 downloadedAVT
# [*********************100%***********************]  1 of 1 downloadedAVX
# [*********************100%***********************]  1 of 1 downloadedAVXL
# [*********************100%***********************]  1 of 1 downloadedAVXS
# [*********************100%***********************]  1 of 1 downloadedAVY
# [*********************100%***********************]  1 of 1 downloadedAWF
# [*********************100%***********************]  1 of 1 downloadedAWI
# [*********************100%***********************]  1 of 1 downloadedAWK
# [*********************100%***********************]  1 of 1 downloadedAWP
# [*********************100%***********************]  1 of 1 downloadedAWR
# [*********************100%***********************]  1 of 1 downloadedAWRE
# [*********************100%***********************]  1 of 1 downloadedAWX
# [*********************100%***********************]  1 of 1 downloadedAXAS
# [*********************100%***********************]  1 of 1 downloadedAXDX
# [*********************100%***********************]  1 of 1 downloadedAXE
# [*********************100%***********************]  1 of 1 downloadedAXGN
# [*********************100%***********************]  1 of 1 downloadedAXL
# [*********************100%***********************]  1 of 1 downloadedAXON
# [*********************100%***********************]  1 of 1 downloadedAXP
# [*********************100%***********************]  1 of 1 downloadedAXR
# [*********************100%***********************]  1 of 1 downloadedAXS
# [*********************100%***********************]  1 of 1 downloadedAXS_D
# [*********************100%***********************]  1 of 1 downloadedAXS_E
# [*********************100%***********************]  1 of 1 downloadedAXSM
# [*********************100%***********************]  1 of 1 downloadedAXTA
# [*********************100%***********************]  1 of 1 downloadedAXTI
# [*********************100%***********************]  1 of 1 downloadedAXU
# [*********************100%***********************]  1 of 1 downloadedAYI
# [*********************100%***********************]  1 of 1 downloadedAYR
# [*********************100%***********************]  1 of 1 downloadedAYTU
# [*********************100%***********************]  1 of 1 downloadedAYX
# [*********************100%***********************]  1 of 1 downloadedAZN
# [*********************100%***********************]  1 of 1 downloadedAZO
# [*********************100%***********************]  1 of 1 downloadedAZPN
# [*********************100%***********************]  1 of 1 downloadedAZRE
# [*********************100%***********************]  1 of 1 downloadedAZRX
# [*********************100%***********************]  1 of 1 downloadedAZUL
# [*********************100%***********************]  1 of 1 downloadedAZZ
# [*********************100%***********************]  1 of 1 downloadedB
# [*********************100%***********************]  1 of 1 downloadedBA
# [*********************100%***********************]  1 of 1 downloadedBAA
# [*********************100%***********************]  1 of 1 downloadedBABA
# [*********************100%***********************]  1 of 1 downloadedBABY
# [*********************100%***********************]  1 of 1 downloadedBAC-WS-A
# [*********************100%***********************]  1 of 1 downloadedBAC-WS-B
# [*********************100%***********************]  1 of 1 downloadedBAC
# [*********************100%***********************]  1 of 1 downloadedBAC_A
# [*********************100%***********************]  1 of 1 downloadedBAC_C
# [*********************100%***********************]  1 of 1 downloadedBAC_D
# [*********************100%***********************]  1 of 1 downloadedBAC_E
# [*********************100%***********************]  1 of 1 downloadedBAC_I
# [*********************100%***********************]  1 of 1 downloadedBAC_L
# [*********************100%***********************]  1 of 1 downloadedBAC_W
# [*********************100%***********************]  1 of 1 downloadedBAC_Y
# [*********************100%***********************]  1 of 1 downloadedBAF
# [*********************100%***********************]  1 of 1 downloadedBAH
# [*********************100%***********************]  1 of 1 downloadedBAK
# [*********************100%***********************]  1 of 1 downloadedBAM
# [*********************100%***********************]  1 of 1 downloadedBANC
# [*********************100%***********************]  1 of 1 downloadedBANC_C
# [*********************100%***********************]  1 of 1 downloadedBANC_D
# [*********************100%***********************]  1 of 1 downloadedBANC_E
# [*********************100%***********************]  1 of 1 downloadedBAND
# [*********************100%***********************]  1 of 1 downloadedBANF
# [*********************100%***********************]  1 of 1 downloadedBANFP
# [*********************100%***********************]  1 of 1 downloadedBANR
# [*********************100%***********************]  1 of 1 downloadedBANX
# [*********************100%***********************]  1 of 1 downloadedBAP
# [*********************100%***********************]  1 of 1 downloadedBAR
# [*********************100%***********************]  1 of 1 downloadedBAS
# [*********************100%***********************]  1 of 1 downloadedBASI
# [*********************100%***********************]  1 of 1 downloadedBATRA
# [*********************100%***********************]  1 of 1 downloadedBATRK
# [*********************100%***********************]  1 of 1 downloadedBAX
# [*********************100%***********************]  1 of 1 downloadedBB
# [*********************100%***********************]  1 of 1 downloadedBBBY
# [*********************100%***********************]  1 of 1 downloadedBBC
# [*********************100%***********************]  1 of 1 downloadedBBD
# [*********************100%***********************]  1 of 1 downloadedBBDO
# [*********************100%***********************]  1 of 1 downloadedBBF
# [*********************100%***********************]  1 of 1 downloadedBBG
# [*********************100%***********************]  1 of 1 downloadedBBGI
# [*********************100%***********************]  1 of 1 downloadedBBK
# [*********************100%***********************]  1 of 1 downloadedBBL
# [*********************100%***********************]  1 of 1 downloadedBBN
# [*********************100%***********************]  1 of 1 downloadedBBOX
# [*********************100%***********************]  1 of 1 downloadedBBRG
# [*********************100%***********************]  1 of 1 downloadedBBSI
# [*********************100%***********************]  1 of 1 downloadedBBT
# [*********************100%***********************]  1 of 1 downloadedBBT_D
# [*********************100%***********************]  1 of 1 downloadedBBT_E
# [*********************100%***********************]  1 of 1 downloadedBBT_F
# [*********************100%***********************]  1 of 1 downloadedBBT_G
# [*********************100%***********************]  1 of 1 downloadedBBT_H
# [*********************100%***********************]  1 of 1 downloadedBBU
# [*********************100%***********************]  1 of 1 downloadedBBVA
# [*********************100%***********************]  1 of 1 downloadedBBW
# [*********************100%***********************]  1 of 1 downloadedBBX
# [*********************100%***********************]  1 of 1 downloadedBBY
# [*********************100%***********************]  1 of 1 downloadedBC
# [*********************100%***********************]  1 of 1 downloadedBCAC
# [*********************100%***********************]  1 of 1 downloadedBCACR
# [*********************100%***********************]  1 of 1 downloadedBCACU
# [*********************100%***********************]  1 of 1 downloadedBCACW
# [*********************100%***********************]  1 of 1 downloadedBCBP
# [*********************100%***********************]  1 of 1 downloadedBCC
# [*********************100%***********************]  1 of 1 downloadedBCD
# [*********************100%***********************]  1 of 1 downloadedBCE
# [*********************100%***********************]  1 of 1 downloadedBCEI
# [*********************100%***********************]  1 of 1 downloadedBCH
# [*********************100%***********************]  1 of 1 downloadedBCI
# [*********************100%***********************]  1 of 1 downloadedBCLI
# [*********************100%***********************]  1 of 1 downloadedBCO
# [*********************100%***********************]  1 of 1 downloadedBCOM
# [*********************100%***********************]  1 of 1 downloadedBCOR
# [*********************100%***********************]  1 of 1 downloadedBCOV
# [*********************100%***********************]  1 of 1 downloadedBCPC
# [*********************100%***********************]  1 of 1 downloadedBCR
# [*********************100%***********************]  1 of 1 downloadedBCRH
# [*********************100%***********************]  1 of 1 downloadedBCRX
# [*********************100%***********************]  1 of 1 downloadedBCS
# [*********************100%***********************]  1 of 1 downloadedBCS_D
# [*********************100%***********************]  1 of 1 downloadedBCTF
# [*********************100%***********************]  1 of 1 downloadedBCV
# [*********************100%***********************]  1 of 1 downloadedBCV_A
# [*********************100%***********************]  1 of 1 downloadedBCX
# [*********************100%***********************]  1 of 1 downloadedBDC
# [*********************100%***********************]  1 of 1 downloadedBDC_B
# [*********************100%***********************]  1 of 1 downloadedBDCZ
# [*********************100%***********************]  1 of 1 downloadedBDGE
# [*********************100%***********************]  1 of 1 downloadedBDJ
# [*********************100%***********************]  1 of 1 downloadedBDL
# [*********************100%***********************]  1 of 1 downloadedBDN

# %%
JD.tail(10)

# %%
JD = get_data('JD')

# %%
BABA = get_data("BABA")

# %%
BABA.Open.plot()

# %%
BABA.tail(10)

# %%
BABA.Open.plot()

# %%
JD.Open.plot()

# %%
symbol = 'AMZN'
data_source='google'
start_date = '2010-01-01'
end_date = '2017-12-10'
df = data.get_data_yahoo(symbol, start_date, end_date)

# %%
from sklearn.preprocessing import MinMaxScaler
def data_normalize(df, col):
    data_close = np.reshape(df[col], (df[col].shape[0], 1))
    scaler = MinMaxScaler()
    result_get = scaler.fit_transform(data_close)
    return result_get

def binning_data(data, num_embedding = 1000):
    bins = np.linspace(0, 1, num_embedding)
    inds = np.digitize(data_get, bins)
    return inds


def get_data(file_name):
    file_name = os.path.join('/notebooks/stock_data_analysis/data_2/Stocks', file_name)
    df = pd.read_csv(file_name, sep=',')
    #combine attributes
    #combine high and low by avg
    #combine open and close by avg
    #combine avgHighLow and avgOpenClose
    df['Price'] = (df['High'] + df['Low'] + df['Open'] + df['Close'])/4
    #take log as this flattens the data more, resulting in a better prediction
    df['Price'] = np.log(df['Price'])

    #drop obsolete columns for faster processing
    columns2Drop = [] #['High', 'Low', 'Open', 'Close', 'OpenInt']
    df = df.drop(labels=columns2Drop, axis=1)

    #create new attribute of "movement"
    df['Volume*Price'] = df['Volume'] * df['Price']
    # print(df)

    label = filename
    df['Label'] = label
    df['Date'] = pd.to_datetime(df['Date'])
    #conver data to an number so we can fit it to LinearRegression()
#     df['Date'] = df['Date'].map(dt.datetime.toordinal)

    #data.append(df)
    return df

# %%
def load_pickle(data_path):
    with open(data_path, 'rb') as handle:
        data_get = pickle.load(handle)
    return data_get

def save_picle(data_path, data):
    with open(data_path, 'wb') as handle:
        pickle.dump(data, handle)

# %%
def exists(path):
    """Test whether a path exists.  Returns False for broken symbolic links"""
    try:
        st = os.stat(path)
    except os.error:
        return False
    return True

# %%
pathModel = os.getcwd()  #
embedding_col_path = os.path.join(pathModel, "data_get.txt")

embedding_save_path = os.path.join(pathModel, "data_embedding.txt")

# %%
flag = exists(embedding_col_path)

# %%
flag

# %%
import json

# %%
if not flag:
    data = []
    for filename in filenames:
        df = get_data(filename)
        binning_sentence = data_normalize(df, 'Close')
        inds = list(binning_data(binning_sentence).flat)
        data.append(inds)
    with open(embedding_col_path, 'w') as f:
        f.write(json.dumps(data))
else:
    #Now read the file back into a Python list object
    with open(embedding_col_path, 'r') as f:
        data = json.loads(f.read())

# %%
len(data)

# %%
import tensorflow as tf

batch_size = 256
embedding_size = 64
generations = 5000
print_loss_every = 500
num_embedding = 1000
num_sampled = int(batch_size/2)    # Number of negative examples to sample.
window_size = 8       # How many words to consider left and right.

# %%
valid_examples = [1,20,30,149,293]

# %%
# Generate data randomly (N words behind, target, N words ahead)
def generate_batch_data(sentences, batch_size, window_size, method='skip_gram'):
    # Fill up data batch
    batch_data = []
    label_data = []
    while len(batch_data) < batch_size:
        # select random sentence to start
        idx = np.random.choice(len(sentences),1)
        rand_sentence = sentences[idx[0]]
        # Generate consecutive windows to look at
        window_sequences = [rand_sentence[max((ix-window_size),0):(ix+window_size+1)] for ix, x in enumerate(rand_sentence)]
        # Denote which element of each window is the center word of interest
        label_indices = [ix if ix<window_size else window_size for ix,x in enumerate(window_sequences)]
        
        # Pull out center word of interest for each window and create a tuple for each window
        if method=='skip_gram':
            batch_and_labels = [(x[y], x[:y] + x[(y+1):]) for x,y in zip(window_sequences, label_indices)]
            # Make it in to a big list of tuples (target word, surrounding word)
            tuple_data = [(x, y_) for x,y in batch_and_labels for y_ in y]
        elif method=='cbow':
            batch_and_labels = [(x[:y] + x[(y+1):], x[y]) for x,y in zip(window_sequences, label_indices)]
            # Make it in to a big list of tuples (target word, surrounding word)
            tuple_data = [(x_, y) for x,y in batch_and_labels for x_ in x]
        else:
            raise ValueError('Method {} not implemented yet.'.format(method))
            
        # extract batch and labels
        batch, labels = [list(x) for x in zip(*tuple_data)]
        batch_data.extend(batch[:batch_size])
        label_data.extend(labels[:batch_size])
    # Trim batch and label at the end
    batch_data = batch_data[:batch_size]
    label_data = label_data[:batch_size]
    
    # Convert to numpy array
    batch_data = np.array(batch_data)
    label_data = np.transpose(np.array([label_data]).astype(int))
    
    return(batch_data, label_data)

# %%
# Define Embeddings:
embeddings = tf.Variable(tf.random_uniform([num_embedding, embedding_size], -1.0, 1.0), name = "product_vec")

# NCE loss parameters
nce_weights = tf.Variable(tf.truncated_normal([num_embedding, embedding_size],
                                               stddev=1.0 / np.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([num_embedding]))

# Create data/target placeholders
x_inputs = tf.placeholder(tf.int32, shape=[batch_size])
y_target = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# Lookup the word embedding:
embed = tf.nn.embedding_lookup(embeddings, x_inputs)

# Get loss from prediction
loss_get = tf.nn.nce_loss(weights=nce_weights,            # Tensor of shape(50000, 128)
                          biases=nce_biases,              # vector of zeros; len(128)
                          labels=y_target,            # labels == context words enums
                          inputs=embed,                   # Tensor of shape(128, 128)
                          num_sampled=num_sampled,        # 64: randomly chosen negative (rare) words
                          num_classes=num_embedding)   # 50000: by construction
loss = tf.reduce_mean(loss_get)

# %%
# Create optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1.0).minimize(loss)

tf.summary.scalar("loss", loss)

merged_summary_op = tf.summary.merge_all()

# %%
# Cosine similarity between words
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
config = tf.ConfigProto()


try:
    sess = tf.Session(config=config)
except:
    sess = tf.Session(config=config)

# %%
#Add variable initializer.
init = tf.global_variables_initializer()
sess.run(init)

# %%
LOG_DIR = '/tmp/testing/stock2vec_11'
#tensorboard --logdir=/tmp/testing/example_2_2
summary_writer = tf.summary.FileWriter(LOG_DIR, graph=tf.get_default_graph())
print_valid_every = 100
# Run the skip gram model.
valid_words = [1,23,10,300]
loss_vec = []
loss_x_vec = []
for i in range(generations):
    batch_inputs, batch_labels = generate_batch_data(data, batch_size, window_size)
    feed_dict = {x_inputs : batch_inputs, y_target : batch_labels}

    # Run the train step
    _, summary = sess.run([optimizer, merged_summary_op], feed_dict=feed_dict)
    
    summary_writer.add_summary(summary, i)

    # Return the loss
    if (i+1) % print_loss_every == 0:
        loss_val = sess.run(loss, feed_dict=feed_dict)
        loss_vec.append(loss_val)
        loss_x_vec.append(i+1)
        print("Loss at step {} : {}".format(i+1, loss_val))
      
    # Validation: Print some random words and top 5 related words
#     if (i+1) % print_valid_every == 0:
#         sim = sess.run(similarity, feed_dict=feed_dict)
#         for j in range(len(valid_words)):
#             valid_word = name_dict[word_dictionary_rev[valid_examples[0]]] #word_dictionary_rev[valid_examples[j]]
#             top_k = 5 # number of nearest neighbors
#             nearest = (-sim[j, :]).argsort()[1:top_k+1]
#             #name_dict[word_dictionary_rev[valid_examples[0]]]
#             log_str = "Nearest to {}::".format(valid_word)
#             for k in range(top_k):
#                 close_word = name_dict[word_dictionary_rev[valid_examples[k]]] #word_dictionary_rev[nearest[k]]
#                 log_str = "%s %s," % (log_str, close_word)
#             print(log_str)
#             print "#################"

# %%
LOG_DIR

# %%
new_df = pd.DataFrame() #creates a new dataframe that's empty
new_df["index"] = range(num_embedding)
import csv
new_df.to_csv(os.path.join(LOG_DIR, 'output2.tsv'), sep='\t', quoting=csv.QUOTE_NONE)

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')

# %%
embeddings_matrix = sess.run(embeddings)

# %%
embeddings_matrix

# %%
pathModel

# %%
np.save(embedding_save_path, embeddings_matrix)

# %%
embedding_save_path = os.path.join(pathModel, "data.npy")

# %%
embedding_save_path = os.path.join(pathModel, "data")
data_get = np.load(embedding_save_path)

# %%
save_picle(embeddings_matrix, embedding_save_path)

# %%
embeddings_matrix.shape

# %%
with open(embedding_save_path, 'w') as f:
    f.write(json.dumps(embeddings_matrix))

# %%
from tensorflow.contrib.tensorboard.plugins import projector
# Create randomly initialized embedding weights which will be trained.

# Format: tensorflow/tensorboard/plugins/projector/projector_config.proto
config = projector.ProjectorConfig()

# You can add multiple embeddings. Here we add only one.
embedding = config.embeddings.add()
embedding.tensor_name = 'product_vec'
# Link this tensor to its metadata file (e.g. labels).
embedding.metadata_path = os.path.join(LOG_DIR, 'output2.tsv')

# Use the same LOG_DIR where you stored your checkpoint.
summary_writer = tf.summary.FileWriter(LOG_DIR)

# The next line writes a projector_config.pbtxt in the LOG_DIR. TensorBoard will
# read this file during startup.
projector.visualize_embeddings(summary_writer, config)

# %%
saver = tf.train.Saver()

saver.save(sess, os.path.join(LOG_DIR, "model.ckpt"), 1000)
